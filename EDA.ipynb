# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd 
import numpy as np

# %%
from utilities import get_participants


participants  = get_participants()
initial_survey = pd.read_csv('./data/Initial_Survey.csv')
summary_survey = pd.read_csv('./data/Summary_Survey.csv')

# %%
print("Participants withoput WEB Inspirations: ", len(participants[participants["WEB_inspirations"].apply(len) == 0]))
print("Participants withoput AI Inspirations: ", len(participants[participants["AI_inspirations"].apply(len) == 0]))
print("Participants withoput Final Submision: ", len(participants[participants["Final_submisions"].apply(len) == 0]))
# Out:
# Participants withoput WEB Inspirations:  27
# Participants withoput AI Inspirations:  26
# Participants withoput Final Submision:  15

# %%
participants.head(10)
# Out:
#                       Name  ID GroupID  \
# 1             Daria Kachan  1A       1
# 2   Aleksandra Skolimowska  1B       1
# 3            Iryna Sidaruk  2A       2
# 4      Agnieszka Musielska  2B       2
# 5     Magdalena Domagalska  3A       3
# 6         Karolina Prodlik  3B       3
# 7         Milena Sielewicz  4A       4
# 8             Joanna Zając  4B       4
# 9              Nela Salwin  5A       5
# 10        Oliwia Konieczna  5B       5
#
#                                      WEB_inspirations  \
# 1   [data\extracted_photos\web\1A_1.jpg, data\extr...
# 2   [data\extracted_photos\web\1B_1.JPG, data\extr...
# 3   [data\extracted_photos\web\2A_1.jpg, data\extr...
# 4   [data\extracted_photos\web\2B_1.jpg, data\extr...
# 5   [data\extracted_photos\web\3A_1.png, data\extr...
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
#
#                                       AI_inspirations Final_submisions Comment
# 1   [data\extracted_photos\ai\1A_11.png, data\extr...               []     NaN
# 2   [data\extracted_photos\ai\1B_11.png, data\extr...               []     NaN
# 3   [data\extracted_photos\ai\2A_11.png, data\extr...               []     NaN
# 4   [data\extracted_photos\ai\2B_11.png, data\extr...               []     NaN
# 5   [data\extracted_photos\ai\3A_11.png, data\extr...               []     NaN
# 6                                                  []               []     NaN
# 7                                                  []               []     NaN
# 8                                                  []               []     NaN
# 9                                                  []               []     NaN
# 10                                                 []               []     NaN

# %%
#Question between 7 and 77: "How do you rate Nth photo genereted by Midjourney.....?"
print(*initial_survey.columns[:7], sep='\n')
print(*initial_survey.columns[77:], sep='\n')
# Out:
# Sygnatura czasowa
# 1. Imię i Nazwisko
# 2. Nr grupy dziekańskiej
# 3. Szukając inspiracji najchętniej korzystam z:
# 4. Czy korzystałaś/ korzystałeś wcześniej z narzędzia "Midjourney"
# 5. Ile spośród wygenerowanych przy pomocy "Midjourney" obrazków zapisałeś w folderze z inspiracjami?
# 6. Jeśli w pytaniu nr 5 odpowiedziałaś/ odpowiedziałeś "mniej niż 10", wyjaśnij co było przyczyną?
# 17. Czy którakolwiek z grafik wygenerowanych przez "Midjourney" zwróciła uwagę na aspekty projektu, o których wcześniej nie myślałaś/ nie myślałeś?
# 18. Jeśli tak, podaj na jaki aspekt zwróciłaś/ zwróciłeś uwagę?
# 19. Jak oceniasz łatwość generowania satysfakcjonujących obrazów przy użyciu "Midjourney"?
#
# Oceń w skali 1–5 (1-bardzo trudno, 2-trudno, 3-średnio, 4-łatwo, 5-bardzo łatwo)
# 20. Czy w przyszłości skorzystasz z narzędzia "Midjourney" poszukując inspiracji w pracy projektowej?
# 21. Prosimy o porównanie dwóch grup obrazków: pierwszej z obrazkami znalezionymi samodzielnie (numerowane od 1 do 10) oraz drugiej wygenerowanej przez "Midjourney" (numerowane od 11 do 20). Która grupa, według Twojej oceny, była bardziej inspirująca pod względem pobudzania kreatywności?
#
# Oceń (1-zdecydowanie obrazki znalezione samodzielnie, 5-oceniam je tak samo, 9-zdecydowanie obrazki wygenerowane przy użyciu "Midjourney")
# 22. Oceń, który z obrazów (spośród wszystkich zgromadzonych) najbardziej pobudził Twoją kreatywność?
# (w odpowiedzi wpisz numer obrazka)
# 23. Miejsce na dodatkowe komentarze/ uwagi:

# %%
summary_survey.head()
# Out:
#             Sygnatura czasowa    1. Imię i Nazwisko  \
# 0  2024/06/05 5:25:29 PM EEST          Daria Kachan
# 1  2024/06/05 5:47:56 PM EEST  Magdalena Domagalska
# 2  2024/06/05 5:48:16 PM EEST      Daniela Bukowska
# 3  2024/06/05 5:49:40 PM EEST      Milena Sielewicz
# 4  2024/06/05 5:51:23 PM EEST         Iryna Sidaruk
#
#     2. Nr grupy dziekańskiej  \
# 0  AWWA gr. 1.1 (II stopień)
# 1  AWWA gr. 1.1 (II stopień)
# 2  AWWA gr. 1.1 (II stopień)
# 3  AWWA gr. 1.1 (II stopień)
# 4  AWWA gr. 1.1 (II stopień)
#
#    3. Wybierz obrazek spośród wszystkich zgromadzonych inspiracji (1-20) i wskaż ten, który miał największe znaczenie dla osiągniętego efektu projektowego (finalnej koncepcji), z uwagi na aspekt EFEKTU ZASKOCZENIA:  \
# 0                                                 10
# 1                                                 15
# 2                                                 17
# 3                                                 12
# 4                                                  5
#
#    4. Wybierz obrazek spośród wszystkich zgromadzonych inspiracji (1-20) i wskaż ten, który miał największe znaczenie dla osiągniętego efektu projektowego (finalnej koncepcji), z uwagi na aspekt INNOWACYJNOŚCI ROZWIĄZAŃ:  \
# 0                                                 11
# 1                                                 20
# 2                                                 12
# 3                                                  3
# 4                                                 14
#
#    5. Wybierz obrazek spośród wszystkich zgromadzonych inspiracji (1-20) i wskaż ten, który miał największe znaczenie dla osiągniętego efektu projektowego (finalnej koncepcji), z uwagi na aspekt JAKOŚCI WIZUALNEJ:  \
# 0                                                 11
# 1                                                 20
# 2                                                 12
# 3                                                  5
# 4                                                 16
#
#    6. Wybierz obrazek spośród wszystkich zgromadzonych inspiracji (1-20) i wskaż ten, który miał największe znaczenie dla osiągniętego efektu projektowego (finalnej koncepcji), z uwagi na aspekt NASTROJU SCENY:  \
# 0                                                 11
# 1                                                 16
# 2                                                 16
# 3                                                  1
# 4                                                 16
#
#    7. Wybierz obrazek spośród wszystkich zgromadzonych inspiracji (1-20) i wskaż ten, który miał największe znaczenie dla osiągniętego efektu projektowego (finalnej koncepcji), z uwagi na aspekt KOLORYSTYKI:  \
# 0                                                 11
# 1                                                 14
# 2                                                 19
# 3                                                 10
# 4                                                  1
#
#    8. Wybierz obrazek spośród wszystkich zgromadzonych inspiracji (1-20) i wskaż ten, który miał największe znaczenie dla osiągniętego efektu projektowego (finalnej koncepcji), z uwagi na aspekt ZESTAWIEŃ MATERIAŁOWYCH:  \
# 0                                                 11
# 1                                                 14
# 2                                                 12
# 3                                                 12
# 4                                                 16
#
#    9. Wybierz obrazek spośród wszystkich zgromadzonych inspiracji (1-20) i wskaż ten, który miał największe znaczenie dla CAŁOKSZTAŁTU osiągniętego efektu projektowego (finalnej koncepcji).  \
# 0                                                 11
# 1                                                 16
# 2                                                 17
# 3                                                 12
# 4                                                 16
#
#   10. Miejsce na dodatkowe komentarze/ uwagi:
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
